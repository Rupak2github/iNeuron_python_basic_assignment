# %% [markdown]
# # 1.you have to write a fun which will take string and return a len of it without using a inbuilt fun len

# %%
def func(string):
    """ This fn will take string as an input"""  
    counter = 0
    for i in string:
        counter += 1
    return (counter)

# %%
func("Rupak")
# Out:
# 5

# %% [markdown]
# # 2 . write a fun which will be able to print an index of all premitive element which you will pass

# %%
def func1(check):
    """ This fn will be used to print primitive element"""  
    if type(check) == list or type(check) == tuple or type(check) == str:
        for i in range(len(check)):
            if type(check[i]) == int or type(check[i]) == bool or type(check[i]) == float or type(check[i]) == str:
                print("index",i,"for primitive element",check[i])
    elif type(check) == dict:
        v = 0
        for i in check:
            if type(i) == int or type(i) == bool or type(i) == float or type(i) == str:
                if type(check[i]) == int or type(check[i]) == bool or type(check[i]) == float or type(check[i]) == str:
                    print("index",v,"Keys",i,"Primitive element",check[i])
                    v += 1
    elif type(check) == set:
        check = list(check)
        for i in range(len(check)):
            if type(check[i]) == int or type(check[i]) == bool or type(check[i]) == float or type(check[i]) == str:
                print("index",i,"for primitive element",check[i])

# %%
func1({False, 1, 2, 3, 4, 5, 0})
# Out:
# index 0 for primitive element False
# index 1 for primitive element 1
# index 2 for primitive element 2
# index 3 for primitive element 3
# index 4 for primitive element 4
# index 5 for primitive element 5

# %% [markdown]
# # 3 . Write a fun which will take input as a dict and give me out as a list of all the values even in case of 2 level nesting it should work .

# %%
d = {"key1" : 5445 , "key2" :"sudh" , 45 : [3,4,5,6], "tuple" : (1,2,3,4),'JJJ12' : {'KK123' : 111123, 'JJJ123': 'India'}}
def func(d):
    """This fuction will take dict as input"""
    l = []
    for i in d: 
        if type(d[i]) == dict:
            k = func(d[i])
            l.extend(k)
        else: 
            l.append(d[i])   
    return l

# %%
func(d)
# Out:
# [5445, 'sudh', [3, 4, 5, 6], (1, 2, 3, 4), 111123, 'India']

# %% [markdown]
# # 4 . write a fun which will take another function as an input and return me an output

# %%
def func2():
    print("Called by func1")
def func1():
    print("Called by main function")
    func2()
func1()
# Out:
# Called by main function
# Called by func1

# %%
def shout(text):
    return text.upper()
def whisper(text):
    return text.lower()

def greet(func):
    """This fuction will take function as an input"""
    greeting = func("I am created by a function passed by an argument")
    print(greeting)

greet(shout)
greet(whisper)
# Out:
# I AM CREATED BY A FUNCTION PASSED BY AN ARGUMENT
# i am created by a function passed by an argument

# %% [markdown]
# # 5. write a function whihc will take multiple list as a input and give me concatnation of all the element as and output

# %%
def multilist(x):
    """This function takes multiple lists as input"""
    l = []
    for i in range(len(x)):
        if type(x[i]) == list:
            r = multilist(x[i])
            l.extend(r)
        else:
            l.append(x[i])  
    return l

# %%
multilist([[1,3,4,5+7j],[2,4,5,6+6j]])
# Out:
# [1, 3, 4, (5+7j), 2, 4, 5, (6+6j)]

# %% [markdown]
# # 6 . write a function which will be able to take a list as an input return an index of each element like a inbuilt index function but even if we have repetative element it should return index

# %%
def indexreturn(l):
    """This will take non-repetative/repetative list as an input"""
    for i in enumerate(l):
        print(i)
    return l

# %%
indexreturn([[1,3,4,5+7j],[2,4,5,6+6j]])
# Out:
# (0, [1, 3, 4, (5+7j)])
# (1, [2, 4, 5, (6+6j)])
# [[1, 3, 4, (5+7j)], [2, 4, 5, (6+6j)]]

# %%
indexreturn([[1,3,4,5+7j],[1,3,4,5+7j]])
# Out:
# (0, [1, 3, 4, (5+7j)])
# (1, [1, 3, 4, (5+7j)])
# [[1, 3, 4, (5+7j)], [1, 3, 4, (5+7j)]]

# %% [markdown]
# # 7 . Write a function which will whould return list of all the file name from a directory .

# %%
import os
def List_name(path):
    """This fn reads the file names from folder"""
    folder = os.listdir(path)
    for filename in folder:
        print("Filename is: ",filename)

# %%
List_name(r'C:\Rupak Banerjee\Entertainment\Apple Wallpapers')
# Out:
# Filename is:  1281568-30-01-2016-steve-jobs-celebrity-background.jpg
# Filename is:  1874589.jpg
# Filename is:  apples_rules-wallpaper-3840x2160.jpg
# Filename is:  apple_19-wallpaper-1920x1080.jpg
# Filename is:  apple_2-wallpaper-3840x2160.jpg
# Filename is:  apple_46-wallpaper-1920x1080.jpg
# Filename is:  apple_blue_logo-wallpaper-2560x1440.jpg
# Filename is:  apple_colorful_spectrum_shade-1920x1200.jpg
# Filename is:  apple_commercial-wallpaper-2560x1440.jpg
# Filename is:  apple_galaxy_blue-wallpaper-2560x1440.jpg
# Filename is:  apple_in_glass_black-1920x1200.jpg
# Filename is:  apple_ipad_background-wallpaper-2560x1440.jpg
# Filename is:  apple_logo_7-wallpaper-1920x1080.jpg
# Filename is:  apple_logo_on_dark_background-wallpaper-1920x1080.jpg
# Filename is:  apple_logo_purple_waves-1920x1200.jpg
# Filename is:  apple_logo_white-wallpaper-2560x1440.jpg
# Filename is:  apple_mac_os_x_mavericks-wallpaper-2560x1440.jpg
# ...

# %% [markdown]
# # 8  . write a function which will be able to show your system configuration .

# %%
import platform
def SystemConfig(my_system):
    """This function takes machine name input"""
    my_system = platform.uname()
    print(f"System: {my_system.system}")
    print(f"Node Name: {my_system.node}")
    print(f"Release: {my_system.release}")
    print(f"Version: {my_system.version}")
    print(f"Machine: {my_system.machine}")
    print(f"Processor: {my_system.processor}")

# %%
SystemConfig(my_system)
# Out:
# System: Windows
# Node Name: LAPTOP-V9F3K9G7
# Release: 10
# Version: 10.0.22000
# Machine: AMD64
# Processor: Intel64 Family 6 Model 140 Stepping 1, GenuineIntel

# %% [markdown]
# # 9 . write a function which will be able to show date and time  .

# %%
import datetime
def dtime(dt):
    """This fn will take datetime as input"""
    dt = datetime.datetime.now()
    print ("Current date and time = %s" % dt)
    print ("Today's date:  = %s/%s/%s" % (dt.day, dt.month, dt.year))
    print ("The time is now: = %s:%s:%s" % (dt.hour, dt.minute, dt.second))

# %%
dtime(dt)

# %% [markdown]
# # 10 . write a function whihc will be able to read a image file and show it to you .

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

def imageread(image):
    """This function takes image file as an input"""
    img = mpimg.imread(image)
    plt.imshow(img)

# %%
imageread(r'C:\Users\rupak\OneDrive\Desktop\leisure_clickss\_DSC1549.jpg')

# %% [markdown]
# # 11 . write a function which can read video file and play for you .

# %%
import cv2
def videoRead(video):
    cap = cv2.VideoCapture(video)
    if (cap.isOpened()== False):
        print("Error opening video stream or file")
    while (cap.isOpened()):
        ret, frame = cap.read()
        if ret == True:
            cv2.imshow('My Video Player', frame)
            if cv2.waitKey(30) & 0xFF == ord('q'):
                break
        else:
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
videoRead(r'C:\Users\rupak\OneDrive\Desktop\Music\Jamming.mp4')

# %% [markdown]
# # 12  . write a function whihc can move a file from one directory to another directory .

# %%
import shutil
import os

def movefile(source,destination,f):
    allfiles = os.listdir(source)
    for f in allfiles:
        shutil.move(source + f,destination + f)

# %%
movefile(r'C:\Users\rupak\OneDrive\Desktop\Music',r'C:\Users\rupak\OneDrive\Desktop\Videos','Jamming.mp4')

# %% [markdown]
# # 13 . write a function which will be able to shutdonw your system .

# %%
import os

def shut_sys(shutdown):
    shutdown = input("do you want to shut? Yes / No: ")
    if shutdown == 'Yes':
        os.system("shutdown /s /t 1")
    else:
        exit()

# %%
shut_sys(No)

# %% [markdown]
# # 14 . write a function whihc will be able to access your mail .

# %%
import smptplib

def mail_send(sender,receiver):
    message = """This is a test e-mail message."""
    try:
        smtpObj = smtplib.SMTP('localhost')
        smtpObj.sendmail(sender, receivers, message)         
        print "Successfully sent email"
    except SMTPException:
        print "Error: unable to send email"

# %%
mail_send('rupakb0@gmail.com','rupakb031@gmail.com')

# %% [markdown]
# # 16. write a func to read a complete PDf file .

# %%
import PyPDF2
def read_pdf(dirr, file):
    """
    This Function will help to read pdf file.
    Input contains the dir and the file path to read the file
    """
    
    # creating a pdf file object
    pdfFileObj = open(dirr+"/"+file, 'rb')

    # creating a pdf reader object
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

    # printing number of pages in pdf file

    # creating a page object
    for i in range(0,pdfReader.getNumPages(),1):
        pageObj = pdfReader.getPage(i)
        # extracting text from page
        print(pageObj.extractText())
    pdfFileObj.close()

# %%
read_pdf("C:\Users\rupak\OneDrive\Desktop\iNeuron\Python_code_samples","For_loop.pdf")

# %% [markdown]
# # 17. Write a function to read a word file.

# %%
import docx2txt
def read_doc(dirr, file):
    """This Function will help to read doc file.Input contains the dir and the file path to read the file"""
    my_text = docx2txt.process(dirr + file)
    print(my_text)

# %%
read_doc("C:\Users\rupak\OneDrive\Desktop\Rupak_resume","Rupak_Banerjee_resume_doc.docx")

# %% [markdown]
# # 18. Write a function which can help you to filter only word file from a directory.

# %%
def list_directory(path):
    """
    Input will the directory
    Output will show doc and docx files present in that directory
    """
    import os
    files = os.listdir(path)
    for f in files:
        cc = ''
        for i in range(len(f)-4,len(f)):
            #print(f[i], end= '')
            cc = cc+f[i]
            if(cc == 'docx' or cc == '.doc'):
                print(f, end ='\n')

# %%
list_directory(r"C:")
# Out:
# Accenture.docx
# AY2021-22 Rupak Banerjee-BPBPB1746M-Computation.doc
# Curriculum vitae_updated.docx
# UDEMY_informatica.docx

# %% [markdown]
# # 19. Write a function by which can print an ip address of your system.

# %%
## importing socket module
import socket
## getting the hostname by socket.gethostname() method

def get_ip_addr():
    """
    This function will help to know the system ip of the device
    """
    hostname = socket.gethostname()
    ## getting the IP address using socket.gethostbyname() method
    ip_address = socket.gethostbyname(hostname)
    ## printing the hostname and ip_address
    print(f"Your System IP Address: {ip_address}")

# %% [markdown]
# # 20. Write a function by which you will be able to append two PDF files.

# %%
import PyPDF2 

def pdf_merge(pd1dir,pd1f,pd2dir,pd2f,pdmfdir,pdfmf):
    
    """
    This function will help to merge two pdf files.
    Input contains -> file directory of pdf 1 file
                      file name of pdf 1 file
                      file directory of pdf 2 file
                      file name of pdf 2 file
                      file directory of merged pdf file
                      file name of merged pdf file
    """

    # Open the files that have to be merged one by one
    #pdf1File = open("C:/Users/arpan/OneDrive/Desktop/cv.pdf", 'rb')
    #pdf2File = open("C:/Users/arpan/OneDrive/Desktop/mydoc.pdf", 'rb')
    
    pdf1File = open(pd1dir+"/"+pd1f, 'rb')
    pdf2File = open(pd2dir+"/"+pd2f, 'rb')
    
    #dirr+"/"+file

    # Read the files that you have opened
    pdf1Reader = PyPDF2.PdfFileReader(pdf1File)
    pdf2Reader = PyPDF2.PdfFileReader(pdf2File)

    # Create a new PdfFileWriter object which represents a blank PDF document
    pdfWriter = PyPDF2.PdfFileWriter()

    # Loop through all the pagenumbers for the first document
    for pageNum in range(pdf1Reader.numPages):
        pageObj = pdf1Reader.getPage(pageNum)
        pdfWriter.addPage(pageObj)

    # Loop through all the pagenumbers for the second document
    for pageNum in range(pdf2Reader.numPages):
        pageObj = pdf2Reader.getPage(pageNum)
        pdfWriter.addPage(pageObj)

    # Now that you have copied all the pages in both the documents, write them into the a new document
    pdfOutputFile = open(pdmfdir+"/"+pdfmf, 'wb')
    pdfWriter.write(pdfOutputFile)

    # Close all the files - Created as well as opened
    pdfOutputFile.close()
    pdf1File.close()
    pdf2File.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3632/3039439986.py in <module>
# ----> 1 import PyPDF2
#       2
#       3 def pdf_merge(pd1dir,pd1f,pd2dir,pd2f,pdmfdir,pdfmf):
#       4
#       5     """
#
# ModuleNotFoundError: No module named 'PyPDF2'
